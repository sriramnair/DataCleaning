# %%
import pandas as pd
import numpy as np
from numpy import nan

# %%
data = pd.read_csv('artwork_sample.csv')

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
norm_height = (data.height - data.height.mean()) / data.height.std()

# %%
data['normalized_height'] = norm_height

# %%
data.groupby('artist').transform('nunique')
# Out:
#    id  accession_number  artistRole  artistId  title  dateText  medium  \
# 0   4                 4           1         1      4         2       3
# 1   4                 4           1         1      4         2       3
# 2   4                 4           1         1      4         2       3
# 3   4                 4           1         1      4         2       3
# 4   6                 6           1         1      6         1       1
# 5   6                 6           1         1      6         1       1
# 6   6                 6           1         1      6         1       1
# 7   6                 6           1         1      6         1       1
# 8   6                 6           1         1      6         1       1
# 9   6                 6           1         1      6         1       1
#
#    creditLine  year  acquisitionYear  dimensions  width  height  depth  units  \
# 0           1     1                1           4      4       4      0      1
# ...

# %%
data['artist_mean_height'] = data.groupby('artist')['height'].transform('mean')

# %%
data
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
#IF we only want to see certgain columns in the data frame
data1 = pd.read_csv('artwork_data.csv', low_memory=False)
data1.filter(items=['height', 'id'])
# Out:
#       height      id
# 0        419    1035
# 1        213    1036
# 2        467    1037
# 3        394    1038
# 4        335    1039
# ...      ...     ...
# 69196    305  122960
# 69197    305  122961
# 69198   2410  121181
# 69199    NaN  112306
# 69200    660  127035
#
# [69201 rows x 2 columns]

# %%
# lets return every column in the dataframe with year in it
data1.filter(regex='(?i)year')
# Out:
#        year  acquisitionYear
# 0       NaN           1922.0
# 1       NaN           1922.0
# 2      1785           1922.0
# 3       NaN           1922.0
# 4      1826           1919.0
# ...     ...              ...
# 69196  1975           2013.0
# 69197  1976           2013.0
# 69198  1996           2013.0
# 69199  2000           2013.0
# 69200  1764           2013.0
#
# [69201 rows x 2 columns]

# %%
# if you wanna import a data frame and only pick certain columns

# %%
# make all column names lowercase
data.columns = [x.lower() for x in data.columns]

# %%
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
#Lets rename a column
data.rename(columns={'thumbnailurl': 'thumbnail'}, inplace=True)

# %%
data.head()
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
#lets do some indexing and filtering 
# lets get the first 5 rows not using head

data.loc[0:4,:]
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
# Now the first 5 columns
data.loc[:, 'id': 'artistid']
# Out:
#      id accession_number          artist artistrole  artistid
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39

# %%
#lets get all aquisition years greater than 1920
data1[data1['acquisitionYear'] > 1920]
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 32       1067           A00033      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title           dateText  \
# ...

# %%
# Lets do the same thing using iloc method
data1.iloc[0:3,:]
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
# 2  1037           A00003  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
# 2  The Preaching of Warning. Verso: An Old Man En...         ?c.1785
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN           1922.0
# 1  Presented by Mrs John Richmond 1922   NaN           1922.0
# ...

# %%
# Lets make the index of the datagframe the ID column
data1.set_index('id',inplace=True)

# %%
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data1
# Out:
#        accession_number              artist artistRole  artistId  \
# id
# 1035             A00001       Blake, Robert     artist        38
# 1036             A00002       Blake, Robert     artist        38
# 1037             A00003       Blake, Robert     artist        38
# 1038             A00004       Blake, Robert     artist        38
# 1039             A00005      Blake, William     artist        39
# ...                 ...                 ...        ...       ...
# 122960           T13865  P-Orridge, Genesis     artist     16646
# 122961           T13866  P-Orridge, Genesis     artist     16646
# 121181           T13867        Hatoum, Mona     artist      2365
# 112306           T13868       Creed, Martin     artist      2760
# 127035           T13869   Brunias, Agostino     artist      3824
#
#                                                     title  \
# id
# 1035    A Figure Bowing before a Seated Old Man with h...
# ...

# %%
#Strips whitespace from the medium column of the data set
data.loc[data.medium.str.contains('\s$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistrole, artistid, title, datetext, medium, creditline, year, acquisitionyear, dimensions, width, height, depth, units, inscription, thumbnailcopyright, thumbnail, url, normalized_height, artist_mean_height]
# Index: []
#
# [0 rows x 22 columns]

# %%
#replace all bad data with NAN
data.loc[data.year.isnull() & data.year.astype(str).str.contains('[^0-9]'), ['year']] = nan

# %%
data1.head()
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                     dateText  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# ...

# %%
#Fill nan values in dataset
data1.fillna({'depth': 0}, inplace=True)

# %%
data1.head()
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                     dateText  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# ...

# %%
#Lets drop some duplicate in this data set
data.drop_duplicates(subset=['artist'])
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 4                            Line engraving on paper
#
#                                           creditline    year  ...  width  \
# 0                Presented by Mrs John Richmond 1922     NaN  ...    394
# 4  Purchased with the assistance of a special gra...  1826.0  ...    243
#
#   height  depth  units  inscription thumbnailcopyright  \
# 0    419    NaN     mm          NaN                NaN
# ...
